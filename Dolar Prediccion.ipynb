# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as ptl
from bokeh.plotting import figure, output_file, show
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#Declarando el dataset, toda la información es sacada de "salarios.csv"
dataset = pd.read_excel("dolarRecords.xlsx")

# %%
#El dataset, así es originalmente.
print(dataset)
# Out:
#        Dia   Compra
# 0     2445  21.4233
# 1     2444  21.1899
# 2     2443  21.1734
# 3     2442  21.4168
# 4     2441  21.4173
# ...    ...      ...
# 2440     5  13.4089
# 2441     4  13.4835
# 2442     3  13.4026
# 2443     2  13.4455
# 2444     1  13.4330
#
# [2445 rows x 2 columns]

# %%
#Ordenando el dataset por salario por orden ascendente.
ordenamiento = dataset.sort_values(by=['Dia'], ignore_index=True)

# %%
#Separando el dataset por tuplas. "x" son los dias, "y" es el precio a compra del dolar.
x = dataset.iloc[:, :1].values #xp
y = dataset.iloc[:, 1].values #sal

# %%
#Declaramiento para posteriormente hacer la regresión lineal.
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.5, random_state=0)

# %%
# #Gráfica de los datos.
# output_file("graficadosimple.html")
# fig = figure()
# #fig.line(x, y, line_width=2)
# fig.circle(x, y, size=10, color="navy", alpha=0.5)
# show(fig)

# %%
#Regresión líneal.

regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
#Entrenamiento

viz_train = ptl
viz_train.scatter(X_train, Y_train, color = 'blue')
viz_train.plot(X_train, regressor.predict(X_train), color = 'black')
viz_train.title('Dias/Valor del Dolar')
viz_train.xlabel('Dias')
viz_train.ylabel('Valor del dolar')
viz_train.show()

# %%
#Test

viz_train = ptl
viz_train.scatter(X_test, Y_test, color = 'red')
viz_train.plot(X_train, regressor.predict(X_train), color = 'black')
viz_train.title('Precio/Dias')
viz_train.xlabel('Dias')
viz_train.ylabel('Precio')
viz_train.show()

# %%
#Porcentaje de datos que se ajustan a la predicción
regressor.score(X_test, Y_test)
# Out:
# 0.731591625315178
